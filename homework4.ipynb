# %%
import requests
import re
import pandas as pd
import json
from datetime import datetime
from lxml import html
from pprint import pprint
from pymongo import MongoClient

# %%
class YandexRuParser:
    host = 'https://yandex.ru/news'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' +
                             'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}

    def parse(self) -> list:
        news_list = []
        response = requests.get(self.host, headers=self.headers)
        dom = html.fromstring(response.text)
        news_elements = dom.xpath("//div[contains(@class,'mg-grid__row mg-grid__row_gap_8 news-top-flexible-stories news-app__top')]/div")
        for element in news_elements:
            news = {
                'title': str(element.xpath(".//h2/text()")[0]),
                'url':  str(element.xpath(".//a[@class='mg-card__link']/@href")[0]),
                'source': str(element.xpath(".//span[@class='mg-card-source__source']/a/text()")[0]),
                'publication_date': str(element.xpath(".//span[@class='mg-card-source__time']/text()")[0])
            }
            news_list.append(news)
        return news_list


if __name__ == '__main__':
    parser = YandexRuParser()
    news_result = parser.parse()
    pprint(news_result)
# Out:
# [{'publication_date': '15:20',
#   'source': 'ТАСС',
#   'title': 'Юлия Пересильд и Владимир Машков расписались на\xa0спускаемом '
#            'аппарате «Союза МС-18»',
#   'url': 'https://yandex.ru/news/story/YUliya_Peresild_i_Vladimir_Mashkov_raspisalis_naspuskaemom_apparate_Soyuza_MS-18--d5c74e373126a2ebbb3dba1775687387?lang=ru&rubric=index&fan=1&stid=ECsOiEWY9XTDVw_K5rEh&t=1634473796&tt=true&persistent_id=4666199945189050626'},
#  {'publication_date': '15:24',
#   'source': 'РБК',
#   'title': 'Песков заявил об отсутствии перспектив для\xa0разговора Путина и '
#            'Зеленского',
#   'url': 'https://yandex.ru/news/story/Peskov_zayavil_ob_otsutstvii_perspektiv_dlyarazgovora_Putina_i_Zelenskogo--d5a59e043e5f37466cfceef2d5becaf6?lang=ru&rubric=index&fan=1&stid=ERwpy4_z04EY9wFF1FHS&t=1634473796&tt=true&persistent_id=4666199945189137406'},
#  {'publication_date': '15:21',
#   'source': 'Советский спорт',
#   'title': 'Исмаилов обдумает возможность третьего боя с\xa0Минеевым после '
#            'восстановления от\xa0поражения',
#   'url': 'https://yandex.ru/sport/story/Ismailov_obdumaet_vozmozhnost_tretego_boya_sMineevym_posle_vosstanovleniya_otporazheniya--0b180bcf0563882ba81115a00254a5d1?lang=ru&rubric=index&fan=1&stid=1Nlwwu2aOv4aLB5KaAMU&t=1634473796&tt=true&persistent_id=4666199945189097183&utm_source=yxnews&utm_medium=desktop'},
#  {'publication_date': '15:12',
#   'source': 'Известия',
#   'title': 'Посол Келин: «Северный поток – 2» готов к\xa0запуску, ожидается '
#            'разрешение ФРГ',
#   'url': 'https://yandex.ru/news/story/Posol_Kelin_Severnyj_potok__2_gotov_kzapusku_ozhidaetsya_razreshenie_FRG--2c981012a9e8de6b6ad99701cf9b51e7?lang=ru&rubric=index&fan=1&stid=KiQTHxqo_Eyd89dCHmAF&t=1634473796&tt=true&persistent_id=4666199945189132672'},
#  {'publication_date': '15:20',
#   'source': 'Lenta.ru',
#   'title': 'Песков: Путин неоднократно выступал с\xa0пророческими заявлениями',
#   'url': 'https://yandex.ru/news/story/Peskov_Putin_neodnokratno_vystupal_sprorocheskimi_zayavleniyami--d3c7932f3978028f2641f404043b1a83?lang=ru&rubric=index&fan=1&stid=hjPiiaue5Hkxui2xW-Ix&t=1634473796&tt=true&persistent_id=4666199945189137854'}]

# %%
class MailRuParser:
    host = 'https://news.mail.ru/'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' +
                             'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}

    def parse(self) -> list:
        news_list = []
        response = requests.get(self.host, headers=self.headers)
        dom = html.fromstring(response.text)
        news_elements = dom.xpath("//ul[@data-module='TrackBlocks']/li[@class='list__item']")
        for element in news_elements:
            news = {
                'title': str(element.xpath(".//text()")[0]),
                'url': str(element.xpath("./a/@href")[0])
            }
            news = self._extend(news)
            news_list.append(news)
        return news_list

    def _extend(self, news: dict) -> dict:
        response = requests.get(news['url'], headers=self.headers)
        dom = html.fromstring(response.text)
        news['source'] = str(dom.xpath("//a[contains(@class,'breadcrumbs__link')]//text()")[0])
        news['publication_date'] = str(dom.xpath("//span[@datetime]/@datetime")[0])
        return news


if __name__ == '__main__':
    parser = MailRuParser()
    news_result = parser.parse()
    pprint(news_result)
# Out:
# [{'publication_date': '2021-10-17T12:06:07+03:00',
#   'source': 'Life.ru',
#   'title': 'В России хотят запретить остановку на\xa0«островках безопасности»',
#   'url': 'https://news.mail.ru/society/48381363/'},
#  {'publication_date': '2021-10-17T00:42:45+03:00',
#   'source': 'Смотрим',
#   'title': 'Кабо-Верде выдала США венесуэльского дипломата',
#   'url': 'https://news.mail.ru/incident/48379037/'},
#  {'publication_date': '2021-10-17T10:55:27+03:00',
#   'source': 'РБК',
#   'title': 'МВД объяснило новый порядок выезда детей за\xa0границу',
#   'url': 'https://news.mail.ru/society/48381361/'},
#  {'publication_date': '2021-10-17T11:03:11+03:00',
#   'source': 'Новости Mail.ru',
#   'title': 'Названы 5 фактов о\xa0Кремлевском дворце, которые стоит узнать',
#   'url': 'https://news.mail.ru/society/48381364/'},
#  {'publication_date': '2021-10-17T12:01:32+03:00',
#   'source': 'Новости Mail.ru',
#   'title': 'В\xa0Московском зоопарке показали лучших самцов-родителей (фото)',
#   'url': 'https://news.mail.ru/society/48381845/'},
#  {'publication_date': '2021-10-17T08:23:34+03:00',
#   'source': 'Газета.Ру',
#   'title': 'Минтранс и\xa0МВД разработали новые дорожные знаки',
#   'url': 'https://news.mail.ru/politics/48380075/'}]

# %%
class LentaRuParser:
    host = 'https://lenta.ru'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' +
                             'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}

    def parse(self) -> list:
        news_list = []
        response = requests.get(self.host, headers=self.headers)
        dom = html.fromstring(response.text)
        news_elements = dom.xpath("//section[contains(@class,'js-top-seven')]//div[@class='item']")
        for element in news_elements:
            news = {
                'title': str(element.xpath("./a/text()")[0]),
                'url':  self.host + str(element.xpath("./a/@href")[0]),
                'source': 'LENTA_RU',
                'publication_date': str(element.xpath("./a/time/@datetime")[0])
            }
            news_list.append(news)
        return news_list


if __name__ == '__main__':
    parser = LentaRuParser()
    news_result = parser.parse()
    pprint(news_result)
# Out:
# [{'publication_date': ' 14:45, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Московские рестораны возьмут на\xa0работу роботов\xa0',
#   'url': 'https://lenta.ruhttps://moslenta.ru/news/moskovskie-restorany-vozmut-na-rabotu-robotov-17-10-2021.htm?utm_source=from_lenta'},
#  {'publication_date': ' 14:45, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Москвичей предупредили о «погодной лихорадке»',
#   'url': 'https://lenta.ru/news/2021/10/17/pogoda/'},
#  {'publication_date': ' 14:42, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Американская телеведущая сделала комплимент Путину',
#   'url': 'https://lenta.ru/news/2021/10/17/compliment/'},
#  {'publication_date': ' 14:34, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'В Израиле предъявили обвинение главарю русской мафии',
#   'url': 'https://lenta.ru/news/2021/10/17/israel/'},
#  {'publication_date': ' 14:28, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Минеев объяснил «бешеную функционалку» Исмаилова допингом',
#   'url': 'https://lenta.ru/news/2021/10/17/dopamedov/'},
#  {'publication_date': ' 14:25, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Еще один российский регион введет QR-коды из-за коронавируса',
#   'url': 'https://lenta.ru/news/2021/10/17/kodi/'},
#  {'publication_date': ' 14:23, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Посольство России прокомментировало гибель российских туристов '
#            'в\xa0Албании',
#   'url': 'https://lenta.ru/news/2021/10/17/mid_comment/'},
#  {'publication_date': ' 14:20, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Названы продукты для поддержания тонуса осенью',
#   'url': 'https://lenta.ru/news/2021/10/17/med/'},
#  {'publication_date': ' 14:06, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'В Кремле заявили об\xa0отсутствии перспектив для встречи Путина '
#            'с\xa0Зеленским',
#   'url': 'https://lenta.ru/news/2021/10/17/pu_ze_meeting/'}]

# %%
client = MongoClient('127.0.0.1', 27017)
db = client['news']

news_result = LentaRuParser().parse()
news_result += YandexRuParser().parse()
news_result += MailRuParser().parse()


db.news.insert_many(news_result)

pprint(news_result)
# Out:
# [{'_id': ObjectId('616c18ba78912609c837ecab'),
#   'publication_date': ' 15:32, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Свидетельница конфликта в\xa0московском метро пообещала '
#            'пожаловаться на\xa0полицейских',
#   'url': 'https://lenta.ru/news/2021/10/17/metro_conflict/'},
#  {'_id': ObjectId('616c18ba78912609c837ecac'),
#   'publication_date': ' 15:26, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Россия депортировала племянника начальника Генштаба афганской '
#            'армии',
#   'url': 'https://lenta.ru/news/2021/10/17/deport/'},
#  {'_id': ObjectId('616c18ba78912609c837ecad'),
#   'publication_date': ' 15:25, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Нурмагомедов поддержал Исмаилова после нокаута от\xa0Минеева',
#   'url': 'https://lenta.ru/news/2021/10/17/nurmagomedov/'},
#  {'_id': ObjectId('616c18ba78912609c837ecae'),
#   'publication_date': ' 15:22, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'В Москве умер бывший сенатор от\xa0Астраханской области',
#   'url': 'https://lenta.ru/news/2021/10/17/astr/'},
#  {'_id': ObjectId('616c18ba78912609c837ecaf'),
#   'publication_date': ' 15:16, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'В российском цирке объяснили нападение медведя на\xa0беременную '
#            'дрессировщицу',
#   'url': 'https://lenta.ru/news/2021/10/17/medved/'},
#  {'_id': ObjectId('616c18ba78912609c837ecb0'),
#   'publication_date': ' 15:14, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Адвокат Поклонской оценил шансы на\xa0ее экстрадицию на\xa0Украину',
#   'url': 'https://lenta.ru/news/2021/10/17/wetdream/'},
#  {'_id': ObjectId('616c18ba78912609c837ecb1'),
#   'publication_date': ' 15:08, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Очевидцы раскрыли подробности смертельного нападения в\xa0'
#            'наркодиспансере Якутска',
#   'url': 'https://lenta.ru/news/2021/10/17/yakytsknapal/'},
#  {'_id': ObjectId('616c18ba78912609c837ecb2'),
#   'publication_date': ' 14:45, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Московские рестораны возьмут на\xa0работу роботов\xa0',
#   'url': 'https://lenta.ruhttps://moslenta.ru/news/moskovskie-restorany-vozmut-na-rabotu-robotov-17-10-2021.htm?utm_source=from_lenta'},
#  {'_id': ObjectId('616c18ba78912609c837ecb3'),
#   'publication_date': ' 14:42, 17 октября 2021',
#   'source': 'LENTA_RU',
#   'title': 'Американская телеведущая сделала комплимент Путину',
#   'url': 'https://lenta.ru/news/2021/10/17/compliment/'},
#  {'_id': ObjectId('616c18ba78912609c837ecb4'),
#   'publication_date': '15:24',
#   'source': 'РБК',
#   'title': 'Песков заявил об отсутствии перспектив для\xa0разговора Путина и '
#            'Зеленского',
#   'url': 'https://yandex.ru/news/story/Peskov_zayavil_ob_otsutstvii_perspektiv_dlyarazgovora_Putina_i_Zelenskogo--d5a59e043e5f37466cfceef2d5becaf6?lang=ru&rubric=index&fan=1&stid=ERwpy4_z9wFF04EY1FHS&t=1634473750&tt=true&persistent_id=166868311'},
#  {'_id': ObjectId('616c18ba78912609c837ecb5'),
#   'publication_date': '15:20',
#   'source': 'ТАСС',
#   'title': 'Юлия Пересильд и Владимир Машков расписались на\xa0спускаемом '
#            'аппарате «Союза МС-18»',
#   'url': 'https://yandex.ru/news/story/YUliya_Peresild_i_Vladimir_Mashkov_raspisalis_naspuskaemom_apparate_Soyuza_MS-18--d5c74e373126a2ebbb3dba1775687387?lang=ru&rubric=index&fan=1&stid=ECsOiEWY9XTDVw_Kjp4z&t=1634473750&tt=true&persistent_id=166791560'},
#  {'_id': ObjectId('616c18ba78912609c837ecb6'),
#   'publication_date': '15:25',
#   'source': 'РИА Новости',
#   'title': 'В\xa0России впервые выявили более 34 тысяч новых случаев COVID-19 '
#            'за\xa0сутки',
#   'url': 'https://yandex.ru/news/story/VRossii_vpervye_vyyavili_bolee_34_tysyach_novykh_sluchaev_COVID-19_zasutki--9e245256b0ea736af1960bffe0a91512?lang=ru&rubric=index&fan=1&stid=OClF4xVLRnsQBhST8Ugk&t=1634473750&tt=true&persistent_id=166860202'},
#  {'_id': ObjectId('616c18ba78912609c837ecb7'),
#   'publication_date': '15:21',
#   'source': 'РИА Новости',
#   'title': 'Минеев нокаутировал Исмаилова и защитил чемпионский пояс AMC Fight '
#            'Nights',
#   'url': 'https://yandex.ru/sport/story/Mineev_nokautiroval_Ismailova_i_zashhitil_chempionskij_poyas_AMC_Fight_Nights--3809d96298266c71c37adeeeac6b85dc?lang=ru&rubric=index&fan=1&stid=wu2aOv4a3y4LiiWrLB5K&t=1634473750&tt=true&persistent_id=166837735&utm_source=yxnews&utm_medium=desktop'},
#  {'_id': ObjectId('616c18ba78912609c837ecb8'),
#   'publication_date': '15:12',
#   'source': 'Известия',
#   'title': 'Посол Келин: «Северный поток – 2» готов к\xa0запуску, ожидается '
#            'разрешение ФРГ',
#   'url': 'https://yandex.ru/news/story/Posol_Kelin_Severnyj_potok__2_gotov_kzapusku_ozhidaetsya_razreshenie_FRG--2c981012a9e8de6b6ad99701cf9b51e7?lang=ru&rubric=index&fan=1&stid=KiQTHxqo_Eyd89dCHmAF&t=1634473750&tt=true&persistent_id=166862575'},
#  {'_id': ObjectId('616c18ba78912609c837ecb9'),
#   'publication_date': '2021-10-17T14:07:59+03:00',
#   'source': 'Погода Mail.ru',
#   'title': 'Опасное «алмазное озеро» в\xa0Австралии привлекло сотни туристов',
#   'url': 'https://news.mail.ru/society/48382757/'},
#  {'_id': ObjectId('616c18ba78912609c837ecba'),
#   'publication_date': '2021-10-17T11:43:11+03:00',
#   'source': 'РБК',
#   'title': '34 303 новых случая COVID-19 выявили в России за сутки',
#   'url': 'https://news.mail.ru/society/48381762/'},
#  {'_id': ObjectId('616c18ba78912609c837ecbb'),
#   'publication_date': '2021-10-17T14:38:51+03:00',
#   'source': 'РБК',
#   'title': 'Киберкоманда из России впервые вышла в\xa0финал The International',
#   'url': 'https://sportmail.ru/news/cybersport/48382962/'},
#  {'_id': ObjectId('616c18ba78912609c837ecbc'),
#   'publication_date': '2021-10-17T00:42:45+03:00',
#   'source': 'Смотрим',
#   'title': 'Кабо-Верде выдала США венесуэльского дипломата',
#   'url': 'https://news.mail.ru/incident/48379037/'},
#  {'_id': ObjectId('616c18ba78912609c837ecbd'),
#   'publication_date': '2021-10-17T10:55:27+03:00',
#   'source': 'РБК',
#   'title': 'МВД объяснило новый порядок выезда детей за\xa0границу',
#   'url': 'https://news.mail.ru/society/48381361/'},
#  {'_id': ObjectId('616c18ba78912609c837ecbe'),
#   'publication_date': '2021-10-17T11:03:11+03:00',
#   'source': 'Новости Mail.ru',
#   'title': 'Названы 5 фактов о\xa0Кремлевском дворце, которые стоит узнать',
#   'url': 'https://news.mail.ru/society/48381364/'}]
