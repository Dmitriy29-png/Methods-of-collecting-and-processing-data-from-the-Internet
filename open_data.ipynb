# %%
import pandas as pd
url = 'https://data.gov.ru/opendata/7710914971-demograph/data-20151002T0951-structure-20151002T0951.csv'
data = pd.read_csv(url, low_memory=False)

# %%
data
# Out:
#     num                         region born_2013 born_2012 born_2012_2013  \
# 0     1           Российская Федерация      12,7      12,7            100
# 1     2  Центральный федеральный округ      10,9        11           99,1
# 2     3           Белгородская область      10,9        11           99,1
# 3     4               Брянская область      10,6      11,1           95,5
# 4     5           Владимирская область      10,7      11,3           94,7
# ..  ...                            ...       ...       ...            ...
# 87   88               Амурская область      13,5        14           96,4
# 88   89            Магаданская область      12,4        12          103,3
# 89   90            Сахалинская область      12,5        12          104,2
# 90   91   Еврейская автономная область      13,1      13,3           98,5
# 91   92            Чукотский авт.округ      12,3      13,8           89,1
#
#    dead_2013 dead_2012 dead_2013_2012 increase_2013 increase_2012  \
# 0       13,5      13,5            100          -0,8          -0,8
# 1       14,1      14,1            100          -3,2          -3,1
# 2       14,4      14,3          100,7          -3,5          -3,3
# 3       16,6      16,5          100,6            -6          -5,4
# 4       16,9      16,9            100          -6,2          -5,6
# ..       ...       ...            ...           ...           ...
# 87      13,9      15,6           89,1          -0,4          -1,6
# 88        12      12,9             93           0,4          -0,9
# 89      13,6      13,7           99,3          -1,1          -1,7
# 90      15,1      15,9             95            -2          -2,6
# 91      10,2        12             85           2,1           1,8
#
#    marriages_2013 marriages_2012 marriages_201_2012 divorce _2013  \
# 0             6,8            6,6                103           4,4
# 1             6,4            6,2              103,2           4,3
# 2             6,8              6              113,3           4,8
# 3             6,1            5,6              108,9           4,4
# 4               6            5,9              101,7           4,6
# ..            ...            ...                ...           ...
# 87            7,4            7,7               96,1           5,9
# 88            8,6            8,3              103,6           6,3
# 89            7,6            7,5              101,3           5,4
# 90            6,8              7               97,1             5
# 91            7,8            7,4              105,4           5,1
#
#    divorce _2012 divorce _2013_2012 divorce_marriage_2013  \
# 0            4,3              102,3                 656,2
# 1              4              107,5                 675,3
# 2            4,3              111,6                 708,7
# 3            3,9              112,8                 719,9
# 4            4,3                107                 771,5
# ..           ...                ...                   ...
# 87           5,5              107,3                 792,5
# 88             7                 90                 729,6
# 89           6,4               84,4                 714,2
# 90           4,8              104,2                   741
# 91           6,4               79,7                 658,2
#
#    divorce_marriage_2013.1
# 0                    647,5
# 1                    655,4
# 2                    712,1
# 3                    689,4
# 4                    736,1
# ..                     ...
# 87                   713,2
# 88                   839,9
# 89                   853,7
# 90                   681,5
# 91                     867
#
# [92 rows x 18 columns]

# %%
resul = data[data['num'] == 25]

# %%
resul
# Out:
#     num              region born_2013 born_2012 born_2012_2013 dead_2013  \
# 24   25  Hенецкий авт.округ      16,2      15,7          103,2      10,3
#
#    dead_2012 dead_2013_2012 increase_2013 increase_2012 marriages_2013  \
# 24      10,5           98,1           5,9           5,2            7,5
#
#    marriages_2012 marriages_201_2012 divorce _2013 divorce _2012  \
# 24              7              107,1           5,7           4,4
#
#    divorce _2013_2012 divorce_marriage_2013 divorce_marriage_2013.1
# 24              129,5                 767,3                   625,9
